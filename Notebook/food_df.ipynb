# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\Final submission\PowerBI\Digital-marketing\Dataset\ifood_df.csv')

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.head()
# Out:
#    Income  Kid home  Teen home  Recency  Wines  Fruits  Meat Products  \
# 0   58138         0          0       58    635      88            546
# 1   46344         1          1       38     11       1              6
# 2   71613         0          0       26    426      49            127
# 3   26646         1          0       26     11       4             20
# 4   58293         1          0       94    173      43            118
#
#    Fish Products  Sweet Products  Gold Prods  Num Deals Purchases  \
# 0            172              88          88                    3
# 1              2               1           6                    2
# 2            111              21          42                    1
# 3             10               3           5                    2
# 4             46              27          15                    5
#
#    NumWebPurchases  Num Catalog Purchases  Num Store Purchases  \
# 0                8                     10                    4
# ...

# %%
items_df = df[['Kid home','Teen home','Wines','Fruits','Meat Products','Fish Products','Sweet Products',
               'Gold Prods','Num Deals Purchases','NumWebVisitsMonth','Complain','Response','Age','Customer_Days',
               'Income']]

# %%
items_df.head()
# Out:
#    Kid home  Teen home  Wines  Fruits  Meat Products  Fish Products  \
# 0         0          0    635      88            546            172
# 1         1          1     11       1              6              2
# 2         0          0    426      49            127            111
# 3         1          0     11       4             20             10
# 4         1          0    173      43            118             46
#
#    Sweet Products  Gold Prods  Num Deals Purchases  NumWebVisitsMonth  \
# 0              88          88                    3                  7
# 1               1           6                    2                  5
# 2              21          42                    1                  4
# 3               3           5                    2                  6
# 4              27          15                    5                  5
#
#    Complain  Response  Age  Customer_Days  Income
# 0         0         1   63           2822   58138
# ...

# %%
items_df.to_csv('market.csv')

# %%
items_df.isnull().sum()
# Out:
# Kid home               0
# Teen home              0
# Wines                  0
# Fruits                 0
# Meat Products          0
# Fish Products          0
# Sweet Products         0
# Gold Prods             0
# Num Deals Purchases    0
# NumWebVisitsMonth      0
# Complain               0
# Response               0
# Age                    0
# Customer_Days          0
# Income                 0
# dtype: int64
